# %%
from itertools import groupby

import pandas as pd

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
columns = ["order_id", "order_date", "order_customer_id", "order_status"]

# %%
orders = pd.read_csv(
    'data/retail_db/orders/part-00000',
    names=columns
)

# %%
orders.columns
# Out:
# Index(['order_id', 'order_date', 'order_customer_id', 'order_status'], dtype='object')

# %%
orders.query('order_status=="COMPLETE"')
# Out:
#        order_id             order_date  order_customer_id order_status
# 2             3  2013-07-25 00:00:00.0              12111     COMPLETE
# 4             5  2013-07-25 00:00:00.0              11318     COMPLETE
# 5             6  2013-07-25 00:00:00.0               7130     COMPLETE
# 6             7  2013-07-25 00:00:00.0               4530     COMPLETE
# 14           15  2013-07-25 00:00:00.0               2568     COMPLETE
# ...         ...                    ...                ...          ...
# 68875     68876  2014-07-06 00:00:00.0               4124     COMPLETE
# 68877     68878  2014-07-08 00:00:00.0               6753     COMPLETE
# 68878     68879  2014-07-09 00:00:00.0                778     COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117     COMPLETE
# 68882     68883  2014-07-23 00:00:00.0               5533     COMPLETE
#
# [22899 rows x 4 columns]

# %%
orders.query('order_status=="COMPLETE" and order_date=="2014-01-01 00:00:00.0"')
# Out:
#        order_id             order_date  order_customer_id order_status
# 25881     25882  2014-01-01 00:00:00.0               4598     COMPLETE
# 25887     25888  2014-01-01 00:00:00.0               6735     COMPLETE
# 25888     25889  2014-01-01 00:00:00.0              10045     COMPLETE
# 25894     25895  2014-01-01 00:00:00.0               1044     COMPLETE
# 25896     25897  2014-01-01 00:00:00.0               6405     COMPLETE
# 25897     25898  2014-01-01 00:00:00.0               3950     COMPLETE
# 25900     25901  2014-01-01 00:00:00.0               3099     COMPLETE
# 25901     25902  2014-01-01 00:00:00.0               6083     COMPLETE
# 25906     25907  2014-01-01 00:00:00.0               3603     COMPLETE
# 25912     25913  2014-01-01 00:00:00.0               9382     COMPLETE
# 25913     25914  2014-01-01 00:00:00.0               9288     COMPLETE
# 25914     25915  2014-01-01 00:00:00.0               2963     COMPLETE
# ...

# %%
orders.query('order_status=="COMPLETE" or order_status=="CLOSED"')
# Out:
#        order_id             order_date  order_customer_id order_status
# 0             1  2013-07-25 00:00:00.0              11599       CLOSED
# 2             3  2013-07-25 00:00:00.0              12111     COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827       CLOSED
# 4             5  2013-07-25 00:00:00.0              11318     COMPLETE
# 5             6  2013-07-25 00:00:00.0               7130     COMPLETE
# ...         ...                    ...                ...          ...
# 68875     68876  2014-07-06 00:00:00.0               4124     COMPLETE
# 68877     68878  2014-07-08 00:00:00.0               6753     COMPLETE
# 68878     68879  2014-07-09 00:00:00.0                778     COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117     COMPLETE
# 68882     68883  2014-07-23 00:00:00.0               5533     COMPLETE
#
# [30455 rows x 4 columns]

# %%
orders.query('order_status==("COMPLETE", "CLOSED")')
# Out:
#        order_id             order_date  order_customer_id order_status
# 0             1  2013-07-25 00:00:00.0              11599       CLOSED
# 2             3  2013-07-25 00:00:00.0              12111     COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827       CLOSED
# 4             5  2013-07-25 00:00:00.0              11318     COMPLETE
# 5             6  2013-07-25 00:00:00.0               7130     COMPLETE
# ...         ...                    ...                ...          ...
# 68875     68876  2014-07-06 00:00:00.0               4124     COMPLETE
# 68877     68878  2014-07-08 00:00:00.0               6753     COMPLETE
# 68878     68879  2014-07-09 00:00:00.0                778     COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117     COMPLETE
# 68882     68883  2014-07-23 00:00:00.0               5533     COMPLETE
#
# [30455 rows x 4 columns]

# %%
orders["order_status"].value_counts()
# Out:
# order_status
# COMPLETE           22899
# PENDING_PAYMENT    15030
# PROCESSING          8275
# PENDING             7610
# CLOSED              7556
# ON_HOLD             3798
# SUSPECTED_FRAUD     1558
# CANCELED            1428
# PAYMENT_REVIEW       729
# Name: count, dtype: int64

# %%
orders.groupby?

# %%
(orders.
 groupby("order_status")["order_id"].
 count())
# Out:
# order_status
# CANCELED            1428
# CLOSED              7556
# COMPLETE           22899
# ON_HOLD             3798
# PAYMENT_REVIEW       729
# PENDING             7610
# PENDING_PAYMENT    15030
# PROCESSING          8275
# SUSPECTED_FRAUD     1558
# Name: order_id, dtype: int64

# %%
(orders.
 groupby("order_status").
 agg('count'))
# Out:
#                  order_id  order_date  order_customer_id
# order_status
# CANCELED             1428        1428               1428
# CLOSED               7556        7556               7556
# COMPLETE            22899       22899              22899
# ON_HOLD              3798        3798               3798
# PAYMENT_REVIEW        729         729                729
# PENDING              7610        7610               7610
# PENDING_PAYMENT     15030       15030              15030
# PROCESSING           8275        8275               8275
# SUSPECTED_FRAUD      1558        1558               1558

# %%
(orders.
 groupby("order_status")["order_id"].
 agg(order_count='count'))
# Out:
#                  order_count
# order_status
# CANCELED                1428
# CLOSED                  7556
# COMPLETE               22899
# ON_HOLD                 3798
# PAYMENT_REVIEW           729
# PENDING                 7610
# PENDING_PAYMENT        15030
# PROCESSING              8275
# SUSPECTED_FRAUD         1558

# %%
orders["order_month"] = orders.apply(lambda order: order.order_date[:7], axis=1)

# %%
orders
# Out:
#        order_id             order_date  order_customer_id     order_status  \
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
#       order_month
# 0         2013-07
# 1         2013-07
# ...

# %%
orders. \
    groupby(["order_month", "order_status"])["order_id"]. \
    agg(order_count="count")
# Out:
#                              order_count
# order_month order_status
# 2013-07     CANCELED                  22
#             CLOSED                   161
#             COMPLETE                 515
#             ON_HOLD                   81
#             PAYMENT_REVIEW            19
# ...                                  ...
# 2014-07     PAYMENT_REVIEW            54
#             PENDING                  517
#             PENDING_PAYMENT          979
#             PROCESSING               561
#             SUSPECTED_FRAUD          101
#
# [117 rows x 1 columns]

# %%
(orders.
 groupby(["order_month", "order_status"])["order_id"].
 agg(order_count="count").
 reset_index())
# Out:
#     order_month     order_status  order_count
# 0       2013-07         CANCELED           22
# 1       2013-07           CLOSED          161
# 2       2013-07         COMPLETE          515
# 3       2013-07          ON_HOLD           81
# 4       2013-07   PAYMENT_REVIEW           19
# ..          ...              ...          ...
# 112     2014-07   PAYMENT_REVIEW           54
# 113     2014-07          PENDING          517
# 114     2014-07  PENDING_PAYMENT          979
# 115     2014-07       PROCESSING          561
# 116     2014-07  SUSPECTED_FRAUD          101
#
# [117 rows x 3 columns]

# %%
def get_column_names(schema, ds_name, sorting_key='column_position', reverse=False):
    column_details = schema[ds_name]
    columns = sorted(column_details, key=lambda col: col[sorting_key], reverse=reverse)
    return [col['column_name'] for col in columns]

# %%
import json
schemas = json.load(open('data/retail_db/schemas.json'))

# %%
order_columns = get_column_names(schemas, 'orders')

# %%
order_columns
# Out:
# ['order_id', 'order_date', 'order_customer_id', 'order_status']

# %%
orders = pd.read_csv(
    'data/retail_db/orders/part-00000',
    names=order_columns
)

# %%
orders
# Out:
#        order_id             order_date  order_customer_id     order_status
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
# [68883 rows x 4 columns]

# %%
customers_columns = get_column_names(schemas, 'customers')

# %%
customers_columns
# Out:
# ['customer_id',
#  'customer_fname',
#  'customer_lname',
#  'customer_email',
#  'customer_password',
#  'customer_street',
#  'customer_city',
#  'customer_state',
#  'customer_zipcode']

# %%
customers = pd.read_csv(
    "data/retail_db/customers/part-00000",
    names=customers_columns
)

# %%
customers
# Out:
#        customer_id customer_fname customer_lname customer_email  \
# 0                1        Richard      Hernandez      XXXXXXXXX
# 1                2           Mary        Barrett      XXXXXXXXX
# 2                3            Ann          Smith      XXXXXXXXX
# 3                4           Mary          Jones      XXXXXXXXX
# 4                5         Robert         Hudson      XXXXXXXXX
# ...            ...            ...            ...            ...
# 12430        12431           Mary           Rios      XXXXXXXXX
# 12431        12432         Angela          Smith      XXXXXXXXX
# 12432        12433       Benjamin         Garcia      XXXXXXXXX
# 12433        12434           Mary          Mills      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
#
#       customer_password             customer_street customer_city  \
# 0             XXXXXXXXX          6303 Heather Plaza   Brownsville
# ...

# %%
departments_columns = get_column_names(schemas, 'departments')

# %%
departments = pd.read_csv(
    "data/retail_db/departments/part-00000",
    names=departments_columns
)

# %%
departments
# Out:
#    department_id department_name
# 0              2         Fitness
# 1              3        Footwear
# 2              4         Apparel
# 3              5            Golf
# 4              6        Outdoors
# 5              7        Fan Shop

# %%
customers = customers.set_index('customer_id')

# %%
orders = orders.set_index('order_customer_id')

# %%
customer_orders = customers.join(orders, how='inner')

# %%
customer_orders
# Out:
#             customer_fname customer_lname customer_email customer_password  \
# customer_id
# 1                  Richard      Hernandez      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# ...                    ...            ...            ...               ...
# 12434                 Mary          Mills      XXXXXXXXX         XXXXXXXXX
# 12434                 Mary          Mills      XXXXXXXXX         XXXXXXXXX
# 12434                 Mary          Mills      XXXXXXXXX         XXXXXXXXX
# 12435                Laura         Horton      XXXXXXXXX         XXXXXXXXX
# 12435                Laura         Horton      XXXXXXXXX         XXXXXXXXX
#
# ...

# %%
customer_orders.shape
# Out:
# (68883, 11)

# %%
customer_orders = customer_orders.reset_index("customer_id")

# %%
customer_orders.groupby("customer_id")["customer_id"].agg(count='count')
# Out:
#              count
# customer_id
# 1                1
# 2                4
# 3                7
# 4                6
# 5                4
# ...            ...
# 12431           16
# 12432           10
# 12433            4
# 12434            8
# 12435            2
#
# [12405 rows x 1 columns]

# %%
customer_orders.groupby("customer_id")["order_id"].agg(order_count='count')
# Out:
#              order_count
# customer_id
# 1                      1
# 2                      4
# 3                      7
# 4                      6
# 5                      4
# ...                  ...
# 12431                 16
# 12432                 10
# 12433                  4
# 12434                  8
# 12435                  2
#
# [12405 rows x 1 columns]

# %%
(customer_orders
.groupby("customer_id")["order_id"]
  .agg(order_count='count')
  .reset_index()
  .query('order_count>=10'))
# Out:
#        customer_id  order_count
# 70              71           10
# 171            172           10
# 173            174           12
# 196            197           11
# 219            221           15
# ...            ...          ...
# 12311        12341           10
# 12317        12347           10
# 12375        12406           10
# 12400        12431           16
# 12401        12432           10
#
# [699 rows x 2 columns]

# %%
orders.sort_values(by="order_id", ascending=True)
# Out:
#                    order_id             order_date     order_status
# order_customer_id
# 11599                     1  2013-07-25 00:00:00.0           CLOSED
# 256                       2  2013-07-25 00:00:00.0  PENDING_PAYMENT
# 12111                     3  2013-07-25 00:00:00.0         COMPLETE
# 8827                      4  2013-07-25 00:00:00.0           CLOSED
# 11318                     5  2013-07-25 00:00:00.0         COMPLETE
# ...                     ...                    ...              ...
# 778                   68879  2014-07-09 00:00:00.0         COMPLETE
# 1117                  68880  2014-07-13 00:00:00.0         COMPLETE
# 2518                  68881  2014-07-19 00:00:00.0  PENDING_PAYMENT
# 10000                 68882  2014-07-22 00:00:00.0          ON_HOLD
# 5533                  68883  2014-07-23 00:00:00.0         COMPLETE
#
# [68883 rows x 3 columns]

# %%
orders.sort_index()
# Out:
#                    order_id             order_date     order_status
# order_customer_id
# 1                     22945  2013-12-13 00:00:00.0         COMPLETE
# 2                     57963  2013-08-02 00:00:00.0          ON_HOLD
# 2                     67863  2013-11-30 00:00:00.0         COMPLETE
# 2                     15192  2013-10-29 00:00:00.0  PENDING_PAYMENT
# 2                     33865  2014-02-18 00:00:00.0         COMPLETE
# ...                     ...                    ...              ...
# 12434                 42915  2014-04-16 00:00:00.0         COMPLETE
# 12434                  4799  2013-08-23 00:00:00.0  PENDING_PAYMENT
# 12434                 13544  2013-10-16 00:00:00.0          PENDING
# 12435                 41643  2014-04-08 00:00:00.0          PENDING
# 12435                 61629  2013-12-21 00:00:00.0         CANCELED
#
# [68883 rows x 3 columns]

# %%
orders.sort_values(by=["order_customer_id", "order_date"], ascending=True)
# Out:
#                    order_id             order_date     order_status
# order_customer_id
# 1                     22945  2013-12-13 00:00:00.0         COMPLETE
# 2                     57963  2013-08-02 00:00:00.0          ON_HOLD
# 2                     15192  2013-10-29 00:00:00.0  PENDING_PAYMENT
# 2                     67863  2013-11-30 00:00:00.0         COMPLETE
# 2                     33865  2014-02-18 00:00:00.0         COMPLETE
# ...                     ...                    ...              ...
# 12434                 61777  2013-12-26 00:00:00.0         COMPLETE
# 12434                 42915  2014-04-16 00:00:00.0         COMPLETE
# 12434                 51800  2014-06-14 00:00:00.0          ON_HOLD
# 12435                 61629  2013-12-21 00:00:00.0         CANCELED
# 12435                 41643  2014-04-08 00:00:00.0          PENDING
#
# [68883 rows x 3 columns]

# %%
orders.sort_values(by=["order_customer_id", "order_date"], ascending=False)
# Out:
#                    order_id             order_date     order_status
# order_customer_id
# 12435                 41643  2014-04-08 00:00:00.0          PENDING
# 12435                 61629  2013-12-21 00:00:00.0         CANCELED
# 12434                 51800  2014-06-14 00:00:00.0          ON_HOLD
# 12434                 42915  2014-04-16 00:00:00.0         COMPLETE
# 12434                 61777  2013-12-26 00:00:00.0         COMPLETE
# ...                     ...                    ...              ...
# 2                     33865  2014-02-18 00:00:00.0         COMPLETE
# 2                     67863  2013-11-30 00:00:00.0         COMPLETE
# 2                     15192  2013-10-29 00:00:00.0  PENDING_PAYMENT
# 2                     57963  2013-08-02 00:00:00.0          ON_HOLD
# 1                     22945  2013-12-13 00:00:00.0         COMPLETE
#
# [68883 rows x 3 columns]

# %%
orders.sort_values(by=["order_customer_id"], ascending=True).sort_values(by=["order_date"], ascending=False)
# Out:
#                    order_id             order_date    order_status
# order_customer_id
# 10699                 57745  2014-07-24 00:00:00.0        COMPLETE
# 3728                  57631  2014-07-24 00:00:00.0          CLOSED
# 3704                  57605  2014-07-24 00:00:00.0         PENDING
# 5944                  57649  2014-07-24 00:00:00.0          CLOSED
# 10809                 57678  2014-07-24 00:00:00.0         PENDING
# ...                     ...                    ...             ...
# 2911                      8  2013-07-25 00:00:00.0      PROCESSING
# 2636                     45  2013-07-25 00:00:00.0        COMPLETE
# 9231                  57786  2013-07-25 00:00:00.0        COMPLETE
# 3593                  57768  2013-07-25 00:00:00.0        COMPLETE
# 6983                     31  2013-07-25 00:00:00.0  PAYMENT_REVIEW
#
# [68883 rows x 3 columns]

# %%
orders.sort_values(by=["order_customer_id", "order_date"], ascending=[False, True])
# Out:
#                    order_id             order_date     order_status
# order_customer_id
# 12435                 61629  2013-12-21 00:00:00.0         CANCELED
# 12435                 41643  2014-04-08 00:00:00.0          PENDING
# 12434                  1868  2013-08-03 00:00:00.0           CLOSED
# 12434                  4799  2013-08-23 00:00:00.0  PENDING_PAYMENT
# 12434                  5303  2013-08-26 00:00:00.0          PENDING
# ...                     ...                    ...              ...
# 2                     57963  2013-08-02 00:00:00.0          ON_HOLD
# 2                     15192  2013-10-29 00:00:00.0  PENDING_PAYMENT
# 2                     67863  2013-11-30 00:00:00.0         COMPLETE
# 2                     33865  2014-02-18 00:00:00.0         COMPLETE
# 1                     22945  2013-12-13 00:00:00.0         COMPLETE
#
# [68883 rows x 3 columns]

# %%
orders
# Out:
#                    order_id             order_date     order_status
# order_customer_id
# 11599                     1  2013-07-25 00:00:00.0           CLOSED
# 256                       2  2013-07-25 00:00:00.0  PENDING_PAYMENT
# 12111                     3  2013-07-25 00:00:00.0         COMPLETE
# 8827                      4  2013-07-25 00:00:00.0           CLOSED
# 11318                     5  2013-07-25 00:00:00.0         COMPLETE
# ...                     ...                    ...              ...
# 778                   68879  2014-07-09 00:00:00.0         COMPLETE
# 1117                  68880  2014-07-13 00:00:00.0         COMPLETE
# 2518                  68881  2014-07-19 00:00:00.0  PENDING_PAYMENT
# 10000                 68882  2014-07-22 00:00:00.0          ON_HOLD
# 5533                  68883  2014-07-23 00:00:00.0         COMPLETE
#
# [68883 rows x 3 columns]

# %%
orders.to_json('data/retail_db/orders.json',
              orient='records',
               lines=True)
